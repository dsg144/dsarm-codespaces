# %% [markdown]
# # Lab 10 Capstone Notebook (Streamlined)
#
# **Student:**
# **Date:**
# **Dataset:** DSARM Synthetic ABCD-style dataset
# **Goal:** Execute your Exercise 10 plan (H1–H3), apply your multiple-testing plan, and export figures/tables for Lab10.pptx.

# %% [markdown]
# ## 1. Setup and Reproducibility
# Record environment details and keep your workflow reproducible.

# %% [markdown]
# ## 2. Pre-Analysis Plan (Copy From Exercise 10)
#
# Keep this section updated as your “single source of truth” while you work.
#
# - Research question:
# - Wave/timepoint(s):
# - Outcome (DV):
# - Primary predictor (IV):
# - Confounder(s):
# - H1 statement:
# - H2 statement:
# - H3 statement (optional):
# - Primary alpha level:
# - Multiple-testing plan (Bonferroni, Holm, BH/FDR, or other):
# - Key inclusion/exclusion rules:

# %% [markdown]
# ## 3. Load Data + Data Preparation
#
# Do all preparation here in one place:
# - Load dataset
# - Use the data dictionary to verify variable names and coding
# - Apply missing-value code rules and type conversions
# - Apply inclusion/exclusion criteria (e.g., wave filter)
# - Create derived variables and recodes needed for H1–H3

# %% [markdown]
# ## 4. Final Analysis Dataset
#
# Create a final analysis dataframe that contains only:
# - DV, IV, confounder(s), and any covariates used
# - Any IDs needed for merges/checks (if applicable)
#
# This is the dataframe you will use for H1–H3.

# %% [markdown]
# ## 5. Sample Description
#
# Create a compact sample description suitable for a poster:
# - Total N (after filtering)
# - Group counts (if applicable)
# - A small demographics/characteristics table (if required)

# %% [markdown]
# ## 6. H1 Analysis (Test + Figure + Brief Diagnostics)
#
# In this section:
# - Run the planned H1 test
# - Record key statistics you will report
# - Create a poster-ready figure (title + labeled axes/units)
# - Note any key assumption/diagnostic checks and what you observed

# %% [markdown]
# ## 7. H2 Analysis (Test + Figure + Brief Diagnostics)
#
# In this section:
# - Run the planned H2 test
# - Record key statistics you will report
# - Create a poster-ready figure (title + labeled axes/units)
# - Note any key assumption/diagnostic checks and what you observed

# %% [markdown]
# ## 8. H3 Analysis (Optional: Confound Check / Adjusted Model)
#
# Complete this section only if your plan includes H3:
# - Run the confound check and/or adjusted model
# - Record key statistics you will report
# - Create a figure if it strengthens interpretation
# - Note any key assumption/diagnostic checks and what you observed

# %% [markdown]
# ## 9. Multiple Testing Correction (Across H1–H3)
#
# Apply your pre-specified correction method and clearly record:
# - Raw p-values for H1–H3 (as applicable)
# - Adjusted p-values (or corrected decision rule)
# - Which conclusions change (if any)

# %% [markdown]
# ## 10. Export Outputs + Deviations Log + Submission Checklist
#
# ### Export outputs
# Save every figure/table used in Lab10.pptx to an `outputs/` folder with clear filenames.
#
# ### Deviations log
# If you deviated from your plan, record what changed and why (briefly, with timestamps if helpful).
#
# ### Submission checklist
# Confirm:
# - Variable names match the data dictionary
# - Figures have titles and labeled axes/units
# - Multiple-testing plan was applied as written
# - Poster language is non-causal and acknowledges uncertainty
